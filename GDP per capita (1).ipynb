# %%
import pandas as pd

# Replace the filename with your actual file name
df = pd.read_csv("cleaned_gdp_structural_data.csv")

# Optional: Preview the first few rows
df.head()
# Out:
#       country  gdp_per_capita  urbanization_rate  industry_share  \
# 0  Bangladesh     1804.349346             39.711       33.920080
# 1  Bangladesh     1702.080284             38.946       33.316094
# 2  Bangladesh     1604.665923             38.177       32.911565
# 3  Bangladesh     1564.208024             37.405       32.852549
# 4  Bangladesh     1462.250503             36.632       31.982814
#
#    agriculture_share  secondary_gross_enrollment_rate  \
# 0          11.217601                        71.821983
# 1          11.632858                        70.293333
# 2          11.999687                        69.013571
# 3          11.975323                        67.220919
# 4          12.480077                        67.421370
#
#    tertiary_gross_enrollment_rate  population_growth  youth_dependency_ratio  \
# 0                       22.839649           1.024234               44.197249
# 1                       23.400167           0.814978               44.763274
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
# Load your cleaned data file (make sure it's in the same folder or give full path)
df = pd.read_csv("cleaned_gdp_structural_data.csv")

# Preview the first few rows
df.head()
# Out:
#       country  gdp_per_capita  urbanization_rate  industry_share  \
# 0  Bangladesh     1804.349346             39.711       33.920080
# 1  Bangladesh     1702.080284             38.946       33.316094
# 2  Bangladesh     1604.665923             38.177       32.911565
# 3  Bangladesh     1564.208024             37.405       32.852549
# 4  Bangladesh     1462.250503             36.632       31.982814
#
#    agriculture_share  secondary_gross_enrollment_rate  \
# 0          11.217601                        71.821983
# 1          11.632858                        70.293333
# 2          11.999687                        69.013571
# 3          11.975323                        67.220919
# 4          12.480077                        67.421370
#
#    tertiary_gross_enrollment_rate  population_growth  youth_dependency_ratio  \
# 0                       22.839649           1.024234               44.197249
# 1                       23.400167           0.814978               44.763274
# ...

# %%
# Shape and column info
print("Shape:", df.shape)
print("\nColumn types:")
print(df.dtypes)
# Out:
# Shape: (159, 42)
#
# Column types:
# country                                       object
# gdp_per_capita                               float64
# urbanization_rate                            float64
# industry_share                               float64
# agriculture_share                            float64
# secondary_gross_enrollment_rate              float64
# tertiary_gross_enrollment_rate               float64
# population_growth                            float64
# youth_dependency_ratio                       float64
# internet_penetration                         float64
# electricity_access                           float64
# inflation_rate                               float64
# trade_percent_gdp                            float64
# fdi_inflow                                   float64
# credit_to_private_sector                     float64
# remittances_percent_gdp                      float64
# govt_consumption_percent_gdp                 float64
# ...

# %%
import pandas as pd

# Load your cleaned CSV file
df = pd.read_csv("cleaned_gdp_structural_data.csv")

# %%
# Check number of rows and columns
print("Shape:", df.shape)

# Check data types for each column
print("\nColumn types:")
print(df.dtypes)
# Out:
# Shape: (159, 42)
#
# Column types:
# country                                       object
# gdp_per_capita                               float64
# urbanization_rate                            float64
# industry_share                               float64
# agriculture_share                            float64
# secondary_gross_enrollment_rate              float64
# tertiary_gross_enrollment_rate               float64
# population_growth                            float64
# youth_dependency_ratio                       float64
# internet_penetration                         float64
# electricity_access                           float64
# inflation_rate                               float64
# trade_percent_gdp                            float64
# fdi_inflow                                   float64
# credit_to_private_sector                     float64
# remittances_percent_gdp                      float64
# govt_consumption_percent_gdp                 float64
# ...

# %%
df.describe().T
# Out:
#                                            count          mean           std  \
# gdp_per_capita                             159.0  8.730740e+02  4.313482e+02
# urbanization_rate                          159.0  2.725268e+01  7.175992e+00
# industry_share                             159.0  2.305102e+01  4.764363e+00
# agriculture_share                          159.0  2.618695e+01  9.858568e+00
# secondary_gross_enrollment_rate            159.0  3.903531e+01  1.786026e+01
# tertiary_gross_enrollment_rate             159.0  9.102550e+00  7.116182e+00
# population_growth                          159.0  2.096059e+00  7.465018e-01
# youth_dependency_ratio                     159.0  6.883769e+01  1.386966e+01
# internet_penetration                       159.0  8.979516e+00  8.475159e+00
# electricity_access                         159.0  6.958164e+01  2.001951e+01
# inflation_rate                             159.0  7.667098e+00  4.362216e+00
# ...

# %%
# Save the cleaned DataFrame to CSV
df.to_csv("cleaned_gdp_structural_data.csv", index=False)

# %%
# Save the cleaned DataFrame to CSV
df.to_csv("cleaned_gdp_structural_data.csv", index=False)

# %%
# 1. Import pandas (only needed once at the start of your notebook)
import pandas as pd

# 2. Generate descriptive statistics and save them
stats_df = df.describe()

# 3. Save the statistics to a CSV file
stats_df.to_csv("summary_statistics.csv")
